# %% [markdown]
# # Assignment 5 CNN Model

# %% [markdown]
# ## Renaming all the files to standardise and easy of labling

# %%
# Renaming all the file in all folders for easy of labling
import os
 
# Function to rename the files
def main():
   
    folder = "Data/test/without_mask"
    for count, filename in enumerate(os.listdir(folder)):
        dst = f"without_mask_ {str(count+10000)}.jpg"
        src =f"{folder}/{filename}"  
        dst =f"{folder}/{dst}"
        os.rename(src, dst)
# Driver Code
if __name__ == '__main__':
    main()

# %% [markdown]
# #### Moving all the file into one folder

# %%
# Move all image files into one folder "model_data"
import shutil
import os
  
# Define the source and destination path
source = "Data/test/with_mask"
destination = "Data/model_data/with_mask"
  
# code to move the files from sub-folder to main folder.
files = os.listdir(source)
for file in files:
    file_name = os.path.join(source, file)
    shutil.move(file_name, destination)
print("Files Moved")
# Out:
# Files Moved

# %% [markdown]
# #### Importing necessary libraries

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os 
from imutils import paths

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dense, Dropout, Flatten

# %%
dataset = "Data/model_data"
imagePaths=list(paths.list_images(dataset))
imagePaths
# Out:
# ['Data/model_data\\without_mask\\without_mask_ 0.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 100.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1000.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10000.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10001.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10002.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10003.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10004.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10005.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10006.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10007.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10008.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10009.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1001.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10010.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10011.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10012.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10013.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10014.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10015.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10016.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10017.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10018.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10019.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1002.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10020.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10021.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10022.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10023.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10024.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10025.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10026.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10027.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10028.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10029.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1003.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10030.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10031.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10032.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10033.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10034.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10035.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10036.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10037.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10038.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10039.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1004.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10040.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10041.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10042.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10043.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10044.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10045.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10046.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10047.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10048.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10049.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1005.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10050.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10051.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10052.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10053.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10054.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10055.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10056.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10057.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10058.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10059.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1006.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10060.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10061.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10062.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10063.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10064.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10065.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10066.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10067.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10068.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10069.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1007.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10070.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10071.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10072.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10073.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10074.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10075.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10076.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10077.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10078.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10079.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1008.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10080.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10081.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10082.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10083.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10084.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10085.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10086.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10087.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10088.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10089.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1009.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10090.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10091.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10092.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10093.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10094.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10095.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10096.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10097.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10098.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10099.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 101.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1010.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10100.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10101.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10102.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10103.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10104.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10105.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10106.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10107.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10108.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10109.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1011.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10110.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10111.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10112.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10113.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10114.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10115.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10116.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10117.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10118.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10119.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1012.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10120.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10121.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10122.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10123.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10124.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10125.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10126.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10127.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10128.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10129.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1013.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10130.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10131.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10132.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10133.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10134.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10135.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10136.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10137.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10138.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10139.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1014.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10140.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10141.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10142.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10143.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10144.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10145.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10146.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10147.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10148.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10149.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1015.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10150.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10151.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10152.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10153.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10154.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10155.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10156.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10157.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10158.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10159.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1016.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10160.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10161.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10162.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 10163.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1017.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1018.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1019.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 102.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1020.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1021.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1022.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1023.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1024.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1025.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1026.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1027.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1028.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1029.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 103.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1030.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1031.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1032.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1033.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1034.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1035.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1036.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1037.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1038.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1039.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 104.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1040.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1041.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1042.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1043.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1044.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1045.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1046.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1047.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1048.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1049.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 105.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1050.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1051.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1052.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1053.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1054.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1055.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1056.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1057.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1058.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1059.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 106.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1060.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1061.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1062.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1063.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1064.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1065.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1066.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1067.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1068.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1069.jpg',
#  'Data/model_data\\without_mask\\without_mask_
jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1747.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1748.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 1749.jpg',
#  'Data/model_data\\without_mask\\without_mask_ 175.jpg',
#  ...]

# %% [markdown]
# ### Inspect the image sizes and get the mean size to apply to model

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.image import imread
import random
from tensorflow.keras.callbacks import EarlyStopping
height=[]
width=[]
for image in os.listdir("Data/model_data/with_mask"):
    image = imread("Data/model_data/with_mask/" + image)
    h, w, colors = image.shape
    height.append(h)
    width.append(w)

# %%
sns.jointplot(x=height, y=width)
plt.show()

# %%
np.mean(height)
# Out:
# 346.0422670509126

# %%
np.mean(width)
# Out:
# 351.26849183477424

# %% [markdown]
# ### Apply labels to each image file

# %%
# Split labels from filenames
data=[]
labels=[]

for i in imagePaths:
    label=i.split(os.path.sep)[-2]
    labels.append(label)
    image = load_img(i,target_size=(345,345))
    image = img_to_array(image)
    image = preprocess_input(image)
    data.append(image)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py:959: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
data = np.array(data,dtype='float32')
labels = np.array(labels)

# %%
labels
# Out:
# array(['without_mask', 'without_mask', 'without_mask', ..., 'with_mask',
#        'with_mask', 'with_mask'], dtype='<U12')

# %%
# Binarize the labels
lb=LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)

# %%
labels
# Out:
# array([[0., 1.],
#        [0., 1.],
#        [0., 1.],
#        ...,
#        [1., 0.],
#        [1., 0.],
#        [1., 0.]], dtype=float32)

# %% [markdown]
# ### Split the data into test and train

# %%
## Splitting of Data

train_X,test_X,train_Y,test_Y = train_test_split(data,labels,test_size=0.20,random_state=10,stratify=labels)

# %%
train_X
# Out:
# array([[[[-0.8666667 , -0.8745098 , -0.8901961 ],
#          [-0.8666667 , -0.8745098 , -0.8901961 ],
#          [-0.8666667 , -0.8745098 , -0.8901961 ],
#          ...,
#          [ 0.6627451 ,  0.70980394,  0.70980394],
#          [ 0.6627451 ,  0.70980394,  0.70980394],
#          [ 0.6627451 ,  0.70980394,  0.70980394]],
#
#         [[-0.8666667 , -0.8745098 , -0.8901961 ],
#          [-0.8666667 , -0.8745098 , -0.8901961 ],
#          [-0.8666667 , -0.8745098 , -0.8901961 ],
#          ...,
#          [ 0.6627451 ,  0.70980394,  0.70980394],
#          [ 0.6627451 ,  0.70980394,  0.70980394],
#          [ 0.6627451 ,  0.70980394,  0.70980394]],
#
#         [[-0.88235295, -0.8901961 , -0.90588236],
#          [-0.88235295, -0.8901961 , -0.90588236],
#          [-0.88235295, -0.8901961 , -0.90588236],
#          ...,
#          [ 0.6313726 ,  0.6784314 ,  0.6784314 ],
#          [ 0.6313726 ,  0.6784314 ,  0.6784314 ],
#          [ 0.6313726 ,  0.6784314 ,  0.6784314 ]],
#
#         ...,
#
#         [[-0.9607843 , -0.99215686, -1.        ],
#          [-0.9607843 , -0.99215686, -1.        ],
#          [-0.9607843 , -0.99215686, -1.        ],
#          ...,
#          [ 0.99215686,  0.92941177, -0.19215685],
#          [ 0.99215686,  0.92941177, -0.19215685],
#          [ 0.99215686,  0.92941177, -0.19215685]],
#
#         [[-0.9529412 , -0.9843137 , -0.99215686],
#          [-0.9529412 , -0.9843137 , -0.99215686],
#          [-0.9529412 , -0.9843137 , -0.99215686],
#          ...,
#          [ 0.9372549 ,  0.8745098 , -0.24705881],
#          [ 0.9372549 ,  0.8745098 , -0.24705881],
#          [ 0.9372549 ,  0.8745098 , -0.24705881]],
#
#         [[-0.9529412 , -0.9843137 , -0.99215686],
#          [-0.9529412 , -0.9843137 , -0.99215686],
#          [-0.9529412 , -0.9843137 , -0.99215686],
#          ...,
#          [ 0.9372549 ,  0.8745098 , -0.24705881],
#          [ 0.9372549 ,  0.8745098 , -0.24705881],
#          [ 0.9372549 ,  0.8745098 , -0.24705881]]],
#
#
#        [[[ 0.7411765 ,  0.75686276,  0.6862745 ],
#          [ 0.7411765 ,  0.73333335,  0.69411767],
#          [ 0.7490196 ,  0.7411765 ,  0.7019608 ],
#          ...,
#          [ 0.39607847,  0.39607847,  0.34901965],
#          [ 0.3803922 ,  0.39607847,  0.34901965],
#          [ 0.39607847,  0.41176474,  0.36470592]],
#
#         [[ 0.7254902 ,  0.7490196 ,  0.67058825],
#          [ 0.7411765 ,  0.73333335,  0.69411767],
#          [ 0.7411765 ,  0.73333335,  0.7019608 ],
#          ...,
#          [ 0.3803922 ,  0.38823533,  0.3411765 ],
#          [ 0.36470592,  0.37254906,  0.32549024],
#          [ 0.36470592,  0.3803922 ,  0.3176471 ]],
#
#         [[ 0.73333335,  0.7490196 ,  0.69411767],
#          [ 0.7490196 ,  0.7411765 ,  0.7019608 ],
#          [ 0.7490196 ,  0.7411765 ,  0.70980394],
#          ...,
#          [ 0.37254906,  0.37254906,  0.32549024],
#          [ 0.35686278,  0.36470592,  0.3176471 ],
#          [ 0.36470592,  0.36470592,  0.3176471 ]],
#
#         ...,
#
#         [[ 0.8117647 ,  0.827451  ,  0.78039217],
#          [ 0.7647059 ,  0.75686276,  0.7411765 ],
#          [ 0.77254903,  0.77254903,  0.7490196 ],
#          ...,
#          [-0.3098039 , -0.29411763, -0.34117645],
#          [-0.19999999, -0.19215685, -0.24705881],
#          [-0.12156862, -0.10588235, -0.16862744]],
#
#         [[ 0.81960785,  0.8352941 ,  0.7882353 ],
#          [ 0.827451  ,  0.8117647 ,  0.8039216 ],
#          [ 0.64705884,  0.6313726 ,  0.6156863 ],
#          ...,
#          [-0.30196077, -0.29411763, -0.3333333 ],
#          [-0.2235294 , -0.21568626, -0.26274508],
#          [-0.15294117, -0.1372549 , -0.18431371]],
#
#         [[ 0.81960785,  0.8352941 ,  0.7882353 ],
#          [ 0.81960785,  0.81960785,  0.7882353 ],
#          [ 0.7411765 ,  0.73333335,  0.7176471 ],
#          ...,
#          [-0.31764704, -0.2862745 , -0.36470586],
#          [-0.23921567, -0.19999999, -0.29411763],
#          [-0.16862744, -0.12156862, -0.21568626]]],
#
#
#        [[[ 0.73333335,  0.8039216 ,  0.79607844],
#          [ 0.73333335,  0.8039216 ,  0.79607844],
#          [ 0.73333335,  0.8039216 ,  0.79607844],
#          ...,
#          [-0.8117647 , -0.88235295, -0.92156863],
#          [-0.8117647 , -0.88235295, -0.92156863],
#          [-0.8117647 , -0.88235295, -0.92156863]],
#
#         [[ 0.73333335,  0.8039216 ,  0.79607844],
#          [ 0.73333335,  0.8039216 ,  0.79607844],
#          [ 0.73333335,  0.8039216 ,  0.79607844],
#          ...,
#          [-0.8117647 , -0.88235295, -0.92156863],
#          [-0.8117647 , -0.88235295, -0.92156863],
#          [-0.8117647 , -0.88235295, -0.92156863]],
#
#         [[ 0.73333335,  0.8039216 ,  0.79607844],
#          [ 0.73333335,  0.8039216 ,  0.79607844],
#          [ 0.73333335,  0.8039216 ,  0.79607844],
#          ...,
#          [-0.8117647 , -0.88235295, -0.92156863],
#          [-0.8117647 , -0.88235295, -0.92156863],
#          [-0.8117647 , -0.88235295, -0.92156863]],
#
#         ...,
#
#         [[-0.8745098 , -0.9529412 , -0.8901961 ],
#          [-0.8745098 , -0.9529412 , -0.8901961 ],
#          [-0.8745098 , -0.9529412 , -0.8901961 ],
#          ...,
#          [-0.6       , -0.7019608 , -0.7490196 ],
#          [-0.6       , -0.7019608 , -0.7490196 ],
#          [-0.6       , -0.7019608 , -0.7490196 ]],
#
#         [[-0.8745098 , -0.9529412 , -0.8901961 ],
#          [-0.8745098 , -0.9529412 , -0.8901961 ],
#          [-0.8745098 , -0.9529412 , -0.8901961 ],
#          ...,
#          [-0.6       , -0.7019608 , -0.7490196 ],
#          [-0.6       , -0.7019608 , -0.7490196 ],
#          [-0.6       , -0.7019608 , -0.7490196 ]],
#
#         [[-0.8745098 , -0.9529412 , -0.8901961 ],
#          [-0.8745098 , -0.9529412 , -0.8901961 ],
#          [-0.8745098 , -0.9529412 , -0.8901961 ],
#          ...,
#          [-0.6       , -0.7019608 , -0.7490196 ],
#          [-0.6       , -0.7019608 , -0.7490196 ],
#          [-0.6       , -0.7019608 , -0.7490196 ]]],
#
#
#        ...,
#
#
#        [[[-0.94509804, -0.9529412 , -0.88235295],
#          [-0.94509804, -0.9529412 , -0.88235295],
#          [-0.94509804, -0.9529412 , -0.88235295],
#          ...,
#          [ 0.49803925,  0.6627451 ,  0.7647059 ],
#          [ 0.49803925,  0.6627451 ,  0.7647059 ],
#          [ 0.49803925,  0.6627451 ,  0.7647059 ]],
#
#         [[-0.94509804, -0.9529412 , -0.8745098 ],
#          [-0.94509804, -0.9529412 , -0.8745098 ],
#          [-0.9372549 , -0.9529412 , -0.8666667 ],
#          ...,
#          [ 0.49803925,  0.6627451 ,  0.7647059 ],
#          [ 0.49803925,  0.6627451 ,  0.7647059 ],
#          [ 0.49803925,  0.6627451 ,  0.7647059 ]],
#
#         [[-0.9372549 , -0.9529412 , -0.8666667 ],
#          [-0.9372549 , -0.9529412 , -0.8666667 ],
#          [-0.9372549 , -0.9529412 , -0.85882354],
#          ...,
#          [ 0.49803925,  0.6627451 ,  0.7647059 ],
#          [ 0.49803925,  0.6627451 ,  0.7647059 ],
#          [ 0.49803925,  0.6627451 ,  0.7647059 ]],
#
#         ...,
#
#         [[ 0.38823533,  0.6784314 ,  0.84313726],
#          [ 0.38823533,  0.6784314 ,  0.84313726],
#          [ 0.3803922 ,  0.6784314 ,  0.84313726],
#          ...,
#          [ 0.64705884,  0.5764706 ,  0.5529412 ],
#          [ 0.654902  ,  0.5921569 ,  0.56078434],
#          [ 0.654902  ,  0.5921569 ,  0.56078434]],
#
#         [[ 0.38823533,  0.67058825,  0.8509804 ],
#          [ 0.38823533,  0.67058825,  0.8509804 ],
#          [ 0.3803922 ,  0.67058825,  0.8509804 ],
#          ...,
#          [ 0.64705884,  0.58431375,  0.5529412 ],
#          [ 0.654902  ,  0.5921569 ,  0.56078434],
#          [ 0.654902  ,  0.5921569 ,  0.56078434]],
#
#         [[ 0.38823533,  0.67058825,  0.85882354],
#          [ 0.38823533,  0.67058825,  0.85882354],
#          [ 0.37254906,  0.6627451 ,  0.8509804 ],
#          ...,
#          [ 0.654902  ,  0.58431375,  0.5529412 ],
#          [ 0.654902  ,  0.5921569 ,  0.56078434],
#          [ 0.654902  ,  0.5921569 ,  0.56078434]]],
#
#
#        [[[ 0.04313731,  0.16078436,  0.21568632],
#          [ 0.04313731,  0.16078436,  0.21568632],
#          [ 0.03529418,  0.15294123,  0.20784318],
#          ...,
#          [ 0.6862745 ,  0.6156863 ,  0.654902  ],
#          [ 0.6784314 ,  0.60784316,  0.64705884],
#          [ 0.6784314 ,  0.60784316,  0.64705884]],
#
#         [[ 0.04313731,  0.16078436,  0.21568632],
#          [ 0.04313731,  0.16078436,  0.21568632],
#          [ 0.03529418,  0.15294123,  0.20784318],
#          ...,
#          [ 0.6862745 ,  0.6156863 ,  0.654902  ],
#          [ 0.6784314 ,  0.60784316,  0.64705884],
#          [ 0.6784314 ,  0.60784316,  0.64705884]],
#
#         [[ 0.04313731,  0.16078436,  0.21568632],
#          [ 0.04313731,  0.16078436,  0.21568632],
#          [ 0.03529418,  0.15294123,  0.20784318],
#          ...,
#          [ 0.67058825,  0.6       ,  0.6392157 ],
#          [ 0.67058825,  0.6       ,  0.6392157 ],
#          [ 0.67058825,  0.6       ,  0.6392157 ]],
#
#         ...,
#
#         [[ 1.        ,  1.        ,  1.        ],
#          [ 1.        ,  1.        ,  1.        ],
#          [ 1.        ,  1.        ,  1.        ],
#          ...,
#          [-0.7647059 , -0.84313726, -0.8509804 ],
#          [-0.6862745 , -0.7647059 , -0.77254903],
#          [-0.6862745 , -0.7647059 , -0.77254903]],
#
#         [[ 1.        ,  1.        ,  1.        ],
#          [ 1.        ,  1.        ,  1.        ],
#          [ 1.        ,  1.        ,  1.        ],
#          ...,
#          [-0.69411767, -0.77254903, -0.78039217],
#          [-0.6392157 , -0.7176471 , -0.7254902 ],
#          [-0.6392157 , -0.7176471 , -0.7254902 ]],
#
#         [[ 1.        ,  1.        ,  1.        ],
#          [ 1.        ,  1.        ,  1.        ],
#          [ 1.        ,  1.        ,  1.        ],
#          ...,
#          [-0.69411767, -0.77254903, -0.78039217],
#          [-0.6392157 , -0.7176471 , -0.7254902 ],
#          [-0.6392157 , -0.7176471 , -0.7254902 ]]],
#
#
#        [[[-0.19215685, -0.26274508, -0.3333333 ],
#          [-0.19215685, -0.26274508, -0.3333333 ],
#          [-0.19215685, -0.26274508, -0.3333333 ],
#          ...,
#          [ 0.56078434,  0.4901961 ,  0.43529415],
#          [ 0.56078434,  0.4901961 ,  0.43529415],
#          [ 0.56078434,  0.4901961 ,  0.43529415]],
#
#         [[-0.19215685, -0.26274508, -0.3333333 ],
#          [-0.19215685, -0.26274508, -0.3333333 ],
#          [-0.19215685, -0.26274508, -0.3333333 ],
#          ...,
#          [ 0.56078434,  0.4901961 ,  0.43529415],
#          [ 0.56078434,  0.4901961 ,  0.43529415],
#          [ 0.56078434,  0.4901961 ,  0.43529415]],
#
#         [[-0.1607843 , -0.23137254, -0.2862745 ],
#          [-0.1607843 , -0.23137254, -0.2862745 ],
#          [-0.1607843 , -0.23137254, -0.2862745 ],
#          ...,
#          [ 0.10588241,  0.03529418, -0.03529412],
#          [ 0.10588241,  0.03529418, -0.03529412],
#          [ 0.10588241,  0.03529418, -0.03529412]],
#
#         ...,
#
#         [[ 0.88235295,  0.7882353 ,  0.69411767],
#          [ 0.88235295,  0.7882353 ,  0.69411767],
#          [ 0.88235295,  0.7882353 ,  0.69411767],
#          ...,
#          [ 0.7019608 ,  0.39607847,  0.15294123],
#          [ 0.7019608 ,  0.39607847,  0.15294123],
#          [ 0.7019608 ,  0.39607847,  0.15294123]],
#
#         [[ 0.88235295,  0.7882353 ,  0.69411767],
#          [ 0.88235295,  0.7882353 ,  0.69411767],
#          [ 0.88235295,  0.7882353 ,  0.69411767],
#          ...,
#          [ 0.6862745 ,  0.3803922 ,  0.13725495],
#          [ 0.6862745 ,  0.3803922 ,  0.13725495],
#          [ 0.6862745 ,  0.3803922 ,  0.13725495]],
#
#         [[ 0.88235295,  0.7882353 ,  0.69411767],
#          [ 0.88235295,  0.7882353 ,  0.69411767],
#          [ 0.88235295,  0.7882353 ,  0.69411767],
#          ...,
#          [ 0.6862745 ,  0.3803922 ,  0.13725495],
#          [ 0.6862745 ,  0.3803922 ,  0.13725495],
#          [ 0.6862745 ,  0.3803922 ,  0.13725495]]]], dtype=float32)

# %%
train_Y.size
# Out:
# 6662

# %%
test_Y.size
# Out:
# 1666

# %%
aug=ImageDataGenerator(
                       rotation_range=20,
                       zoom_range=0.1,width_shift_range=0.1,
                       height_shift_range=0.1,shear_range=0.1,
                       horizontal_flip=True,
                       vertical_flip=True,
                       fill_mode='nearest'
                       )

# %%
input_shape = (345,345,3)

# %%
# Build Model
model=Sequential()
input_image = Input(shape=input_shape)
# 1st Conv layer
model = Conv2D(16, (3, 3), activation='relu', padding='same', input_shape=input_shape)(input_image)
model = MaxPooling2D((2, 2),padding='same')(model)
# 2nd Conv layer
model = Conv2D(32, (3, 3), activation='relu', padding='same')(model)
model = MaxPooling2D((2, 2),padding='same')(model)
# 3rd Conv layer
model = Conv2D(64, (3, 3), activation='relu', padding='same')(model)
model = MaxPooling2D((2, 2),padding='same')(model)
# 4th Conv layer
model = Conv2D(128, (3, 3), activation='relu', padding='same')(model)
model = MaxPooling2D((2, 2),padding='same')(model)
# 5th Conv layer
model = Conv2D(256, (3, 3), activation='relu', padding='same')(model)
model = MaxPooling2D((2, 2),padding='same')(model)
# FC layers
model = Flatten()(model)
model = Dense(1024)(model)
model = Dropout(0.2)(model)
model = Dense(64)(model)
model = Dropout(0.2)(model)

output= Dense(2, activation='softmax')(model)
model = Model(inputs=[input_image], outputs=[output])

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 345, 345, 3)]     0
#
#  conv2d_5 (Conv2D)           (None, 345, 345, 16)      448
#
#  max_pooling2d_5 (MaxPooling  (None, 173, 173, 16)     0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 173, 173, 32)      4640
#
#  max_pooling2d_6 (MaxPooling  (None, 87, 87, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 44, 44, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 44, 44, 128)       73856
#
#  max_pooling2d_8 (MaxPooling  (None, 22, 22, 128)      0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 22, 22, 256)       295168
#
#  max_pooling2d_9 (MaxPooling  (None, 11, 11, 256)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_3 (Dense)             (None, 1024)              31720448
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 64)                65600
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 32,178,786
# Trainable params: 32,178,786
# Non-trainable params: 0
# _________________________________________________________________

# %%
lr=0.0005
Epochs=16
BS=32
early_stop = EarlyStopping(monitor='val_loss', patience=2)
opt=Adam(learning_rate=lr,decay=lr/Epochs)

# %%
model.compile(loss='binary_crossentropy',optimizer=opt,metrics=['accuracy'])

# %% [markdown]
# ## Training the Model

# %%
history=model.fit(
aug.flow(train_X,train_Y,batch_size=BS),
steps_per_epoch=len(train_X)//BS,
validation_data=(test_X,test_Y),
validation_steps=len(test_X)//BS,
epochs=Epochs
# ,callbacks=[early_stop]    
)
# Out:
# Epoch 1/16
# 104/104 [==============================] - 136s 1s/step - loss: 0.4543 - accuracy: 0.8136 - val_loss: 0.4875 - val_accuracy: 0.7227
# Epoch 2/16
# 104/104 [==============================] - 137s 1s/step - loss: 0.3423 - accuracy: 0.8806 - val_loss: 0.2464 - val_accuracy: 0.9088
# Epoch 3/16
# 104/104 [==============================] - 132s 1s/step - loss: 0.2537 - accuracy: 0.9079 - val_loss: 0.1794 - val_accuracy: 0.9328
# Epoch 4/16
# 104/104 [==============================] - 129s 1s/step - loss: 0.2385 - accuracy: 0.9169 - val_loss: 0.1815 - val_accuracy: 0.9376
# Epoch 5/16
# 104/104 [==============================] - 131s 1s/step - loss: 0.1994 - accuracy: 0.9297 - val_loss: 0.1375 - val_accuracy: 0.9496
# Epoch 6/16
# 104/104 [==============================] - 133s 1s/step - loss: 0.1800 - accuracy: 0.9373 - val_loss: 0.1550 - val_accuracy: 0.9436
# Epoch 7/16
# 104/104 [==============================] - 129s 1s/step - loss: 0.1598 - accuracy: 0.9482 - val_loss: 0.1974 - val_accuracy: 0.9268
# Epoch 8/16
# 104/104 [==============================] - 130s 1s/step - loss: 0.1490 - accuracy: 0.9454 - val_loss: 0.1123 - val_accuracy: 0.9592
# Epoch 9/16
# 104/104 [==============================] - 129s 1s/step - loss: 0.1364 - accuracy: 0.9506 - val_loss: 0.0966 - val_accuracy: 0.9712
# Epoch 10/16
# 104/104 [==============================] - 129s 1s/step - loss: 0.1329 - accuracy: 0.9533 - val_loss: 0.0970 - val_accuracy: 0.9688
# Epoch 11/16
# 104/104 [==============================] - 130s 1s/step - loss: 0.1554 - accuracy: 0.9476 - val_loss: 0.1696 - val_accuracy: 0.9424
# Epoch 12/16
# 104/104 [==============================] - 129s 1s/step - loss: 0.1398 - accuracy: 0.9506 - val_loss: 0.1136 - val_accuracy: 0.9604
# Epoch 13/16
# 104/104 [==============================] - 128s 1s/step - loss: 0.1308 - accuracy: 0.9521 - val_loss: 0.0889 - val_accuracy: 0.9688
# Epoch 14/16
# 104/104 [==============================] - 128s 1s/step - loss: 0.1192 - accuracy: 0.9603 - val_loss: 0.0870 - val_accuracy: 0.9640
# Epoch 15/16
# 104/104 [==============================] - 130s 1s/step - loss: 0.0986 - accuracy: 0.9642 - val_loss: 0.0733 - val_accuracy: 0.9736
# Epoch 16/16
# 104/104 [==============================] - 128s 1s/step - loss: 0.1216 - accuracy: 0.9530 - val_loss: 0.0983 - val_accuracy: 0.9652

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']
epochs = range(1,17)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc_train = history.history['accuracy']
acc_val = history.history['val_accuracy']
epochs = range(1,17)
plt.plot(epochs, acc_train, 'g', label='Training accuracy')
plt.plot(epochs, acc_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.show()

# %% [markdown]
# ## Save Model and Test Model

# %%
model.save('face_mask_detection.h5')

# %%
from tensorflow.keras.models import load_model
model = load_model("face_mask_detection.h5")
predict=model.predict(test_X,batch_size=BS)
predict=np.argmax(predict,axis=1)
print(classification_report(test_Y.argmax(axis=1),predict,target_names=lb.classes_))
# Out:
# 27/27 [==============================] - 5s 162ms/step
#               precision    recall  f1-score   support
#
#    with_mask       0.98      0.95      0.96       417
# without_mask       0.95      0.98      0.97       416
#
#     accuracy                           0.97       833
#    macro avg       0.97      0.97      0.97       833
# weighted avg       0.97      0.97      0.97       833

# %% [markdown]
# ### The End!
